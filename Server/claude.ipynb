# %%
# %pip install --upgrade --quiet anthropic
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()

import anthropic
import base64
import httpx

# First fetch the file
pdf_url = "https://www.math.purdue.edu/~yipn/421/2024-11-05-NetFlows.pdf"
pdf_data = base64.standard_b64encode(httpx.get(pdf_url).content).decode("utf-8")


# Finally send the API request
client = anthropic.Anthropic()
message = client.beta.messages.create(
    model="claude-3-5-sonnet-20241022",
    betas=["pdfs-2024-09-25"],
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "document",
                    "source": {
                        "type": "base64",
                        "media_type": "application/pdf",
                        "data": pdf_data
                    }
                },
                {
                    "type": "text",
                    "text": "I am a student trying to understand notes provided by my professor. The class is titled: Linear Programming and Optimization Techniques. Provide a page by page summary of the document."
                }
            ]
        }
    ],
)

print(message.content)
# Out:
# [BetaTextBlock(text="I'll provide a page-by-page summary of the network flow chapter notes:\n\nPage 1: Introduction to Network Flow (Chapter 14)\n- Defines basic network components:\n- N = set of nodes\n- A = set of directed arcs between nodes (i,j)\n- Introduces basic network diagram notation\n\nPage 2: Network Flow Components\n- Introduces bi values representing supply (bi>0) and demand (bi<0) at nodes\n- Defines Xij as amount transported from node i to j\n- Defines Cij as transportation cost from i to j\n- Presents objective function: minimize sum of CijXij\n\nPage 3: Balance Equations\n- Shows balanced flow equation at node k\n- Presents mathematical formulation with sum of incoming flows minus outgoing flows equals node demand/supply\n- Introduces matrix notation min CTX subject to AX=-b\n\nPages 4-5: Spanning Trees and Network Components\n- Shows examples of connected vs disconnected networks\n- Defines key terms: Path, Cycle, Tree, Spanning Tree\n- Illustrates concepts with ne
# ...

# %%
print(message.content[0].text)
# Out:
# I'll provide a page-by-page summary of the network flow chapter notes:
#
# Page 1: Introduction to Network Flow (Chapter 14)
# - Defines basic network components:
# - N = set of nodes
# - A = set of directed arcs between nodes (i,j)
# - Introduces basic network diagram notation
#
# Page 2: Network Flow Components
# - Introduces bi values representing supply (bi>0) and demand (bi<0) at nodes
# - Defines Xij as amount transported from node i to j
# - Defines Cij as transportation cost from i to j
# - Presents objective function: minimize sum of CijXij
#
# Page 3: Balance Equations
# - Shows balanced flow equation at node k
# - Presents mathematical formulation with sum of incoming flows minus outgoing flows equals node demand/supply
# - Introduces matrix notation min CTX subject to AX=-b
#
# Pages 4-5: Spanning Trees and Network Components
# - Shows examples of connected vs disconnected networks
# - Defines key terms: Path, Cycle, Tree, Spanning Tree
# ...
