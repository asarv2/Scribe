# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_google_genai import ChatGoogleGenerativeAI
from PIL import Image
from langchain_core.messages import HumanMessage, AIMessage
import base64
import io

llm = ChatGoogleGenerativeAI(
    model = 'gemini-1.5-flash-8b',
    temperature = 0,
    max_tokens = None,
    timeout = None,
    max_retries = 2
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732546345.981135 109658680 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported

# %%
content = """Week 1 (Aug 20, 22):
[V, Chapter 1, 2]; [MG, Chapter 1, 2, 4, 5]; [C, Chapter 1, 2, 3].
Examples of linear programming;
Simplex method.

Examples of diet problems: [MG], [C].

Homework 1: due Thursday, Aug 29th, in class.
[V] (make sure you have the 5th Edition.)
Chapter 1, Exercises, p.8: #1.2;
Chapter 2, Exercises, p.21: #2.1, 2.2, 2.5, 2.10;
(Use simplex method to solve 2.1, 2.2, 2.5, following the procedure in p.11-14. For 2.2 and 2.5, you also need to draw in R^2 the feasible set and also the sequence of vertices you go through during the simplex method. For your graphs, use one page for each problem. See p.21 for an example of such a graph. For 2.10, you can use whatever method. If you can "visualize" the geometry of the problem, even in R^4, then the solution is extremely simple.)
Chapter 4, Exercises, p.57: #4.9
(Read [V, p.45] for a motivation of this problem. One method of solution seems to be by mathematical induction, though I haven't tried it myself.)

Week 2 (Aug 27, 29):
[V, Chapter 1, 2]; [MG, Chapter 1, 2, 4, 5]; [C, Chapter 1, 2, 3].
Examples of simplex method.
Choice of initial point, Phase I and Phase II.
Some pitfalls of simplex method:
non-uniqueness [C] p.23;
unboundedness;
degeneracy;
cycling; lexicographic method and Bland's rule.

Note: Examples of simplex method

Homework 2: due Thursday, Sept 5th, in class.
[C]
p.9: #1.2 (Use simplex method to solve the actual minimization problem. In addition, can you think of a "simpler" method to solve this problem? Recall [V] Chapter 2, p.21, #2.10.)
p.9: #1.3 (Prove by using simplex method AND also by graphing.)
p.26: #2.2;
p.44: #3.9(a);
[V] (make sure you have the 5th Edition.)
Chapter 3, Exercises, p.40: #3.4;
Chapter 3, For the cycling example in p.29, which step does the sequence violate Bland rule? Then use Bland rule to fix the cycling problem and find the optimal solution for this example.

Week 3 (Sept 3, 5):
[MG, Section 5.7] Pivoting rules:
Largest coefficient, largest increase, steepest slope, random, etc

[V, Chapter 4][C, Chapter 4][MG Section 5.9]
Efficiency of simplex method: average vs worst case analysis;
Klee-Minty example;
([MG, Chapter 7] Peek at other methods: ellipsoid and interior point methods.)

[V, Chapter 5][C, Chapter 5][MG, Chapter 6]
Duality, primal (P) and dual (D) problems;
Upper and lower bounds, duality gap, Weak Duality Theorem [V, Thm. 5.1].

Note: Efficiency of Simplex Method

Homework 3: due Thursday, Sept 12th, in class.
[C]:
Use Bland rule to do the cycling example in [C] p.31.
[V]:
Chapter 4: 4.1, 4.2, 4.3. (For each problem, provide graphical illustrations.)
Chapter 5: 5.1, 5.2, 5.3, 5.4.
You can use the pivoting app. provided by the texbook to aid your computations.
For 5.2, 5.3, 5.4, ``illustrate'' means that for any optimal solution of the primal problem, find the optimal solution of the dual problem and verify that the objective functional values of the primal and dual problems are the same.

Week 4 (Sept 10, 12):
[V, Chapter 5][C, Chapter 5][MG, Chapter 6]
Duality, primal (P) and dual (D) problems;
Complementary variables: x_j vs z_j, and w_i vs y_i;
Matrix representation of (P) and (D), preservation of negative transpose of matrices during simplex iterations;
Stong Duality Theorem [V, Thm. 5.2];
Complementary Slackness [V, Thm. 5.3];
Certificate of Optimality.
Given (optimal) X, how to find (optimal) Y?

Note: Duality

Homework 4: due Thursday, Sept 19th, in class.
[V] (Re-)do Exercises #2.10, #3.4, #3.5 by considering their dual problems;
[V] #5.6.
[C] Chapter 5, p.69, #5.3

Week 5 (Sept 17, 19):

Interpretation of duality: Cost vs profit.
Duality in general form.

Note: Duality of Diet Problem
Note: General Duality
See also:
Convex Optimization (Chapter 5), by Boyd and Vandenberghe
The Theory of Linear Economic Models (Chapter 1), by Gale.

Homework 5: due Thursday, Sept 26th, in class.
[V] p.83: #5.12, 5.16

Week 6 (Sept 24, 26):

[V] Chapter 5: Simplex in matrix form.
[V] Chapter 6: Sensitivity analysis.

Note: Simplex in Matrix Form
Note: Sensitivity Analysis

Homework 6: due Thursday, Oct 3rd, in class.
[V] Exercises
Chapter 5: 5.14;
Chapter 6: 6.1, 6.6;
Chapter 7: 7.1, 7.2.

Week 7 (Oct 1, 3):

Further applications of duality:
sensitivity and duality; [C] p.67
dual simplex method; [V] Chapter 5.6;
dual phase I method; [V] Chapter 5.7;
[V] Chapter 8.3: Revised simplex method.

Note: Sensitivity and Duality
Note: Dual of General LP
Note: Dual Simplex Method

Homework 7: due Tuesday, Oct 15th, in class.
[V] Exercises: 5.7, 5.8, 6.7;
[C] Problems: 9.2, 9.5.
(For 9.5, you do not need to extend Theorems 5.2 and 5.3. Simply determine if the suggested solution is optimal or not.)

Week 8 (Oct 8, 10):
(Oct 8: October Break)

[V, Chapter 12]
Data regression: L^2 versus L^1;
L^1 minimization as an LP problem.

Week 9 (Oct 15, 17):
Midterm: Thursday, Oct 17th, in class.
No calculator or any electronic devices are allowed (or needed).
Necessary formula will be provided inside the exam.

Note: Selected Homework Solutions

Midterm Statistics: Average = 79.06;
A: >= 85 (8); B >= 70 (4); C >=55 (3); D < 54 (1).
Midterm Solution

Homework 8: due Thursday, Oct 24th, in class.
[V] Exercises: 12.1, 12.2, 12.3, 12.4, 12.7
In addition, do the L^\infinity-error regression for Figure 12.8.
For 12.1, 12.2 and the L^\infinity versions, plot/compare/contrast in the same graph your regression lines.

Week 10 (Oct 22, 24):

[V Chapter 12]
L^2, L^1, L^infinity-regression;
Binary classification;
[MG Chapter 2.6] Biggest ball inside a convex polyhedron

[V Chapter 10] Convex analysis
Convex set, convex combination, convex hull
Caratheodory Theorem (Thm 10.3)
Separation Theorem (Thm 10.4)
Farkas Lemma (Lem 10.5)

Note: Regression
Note: Convex Analysis

Homework 9, due: Thursday, Oct 31st, in class.
Some hints for Homework 9

Week 11 (Oct 29, 31):

Note: Farkas Lemma
Note: Examples and Applications of Linear Programming
Note: Integer Linear Programming

Homework 10: due Thursday, Nov 7th, in class.
[V] p.414, Exercises: 23.4, 23.5

Week 12 (Nov 5, 7):

[V Chapter 14]
Nodes, arcs, networks, incidence matrices, spanning trees.
Basic solutions in terms of spanning trees.
Network primal and dual simplex methods: modification of spanning trees.
Updating of primal, dual and dual slack variables.

Note: Network Flows
Note: Network Simplex Methods

Week 13 (Nov 12, 14):

Integrality Theorem [V, Thm 14.2],
Konig (Matching) Theorem [V, Thm 14.3]
Transshipment, transportation and assignment problems.
Inequality constraints for network flow problems [C, p.321]
Upper bounded network flows [V, 15.4]
Shortest path (as a network flow problem),
Bellman equation (label correcting), Dijkstra algorithm (label setting).

Note: Variants of Network Flows and Applications

Homework 11, due: Tuesday, Nov 26th, in class.
Note: Some guidelines for Homework 11

Week 14 (Nov 19, 21):

Note: Max-Flow-Min-Cut
Note: Economic Interpretation of Network Simplex"""
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# /var/folders/fp/lxwzhd7s73z17lg4p9w_6kfc0000gp/T/ipykernel_46082/1420210082.py:1: SyntaxWarning: invalid escape sequence '\i'
#   content = """Week 1 (Aug 20, 22):

# %%
# prompt = "Using the content provided, create a summary of the course. You should seperate the summary into the following three sections: Key Concepts, Key Problem Types, and Key Algorithm Solutions."
prompt = "Using the content provided, generate a list of all the key terms and concepts in the course. Output the hierarchal list in markdown format."

message = HumanMessage(
    content=[
        {
            "type": "text", 
            "text": prompt
        },
        {
            "type": "text",
            "text": content
        }
    ]
)

response = llm.generate([[message]])
print(response)
# Out:
# generations=[[ChatGeneration(text='# Linear Programming Course Key Terms and Concepts\n\n## Week 1\n\n* **Linear Programming:**  A mathematical method for optimizing a linear objective function subject to linear constraints.\n* **Simplex Method:** An algorithm for solving linear programming problems.\n* **Diet Problems:** A type of linear programming problem focused on optimizing the cost of a diet.\n\n\n## Week 2\n\n* **Simplex Method (Examples):**  Illustrative applications of the simplex algorithm.\n* **Choice of Initial Point:**  Selecting a starting point for the simplex method.\n* **Phase I and Phase II:**  Stages in the simplex method, often used for problems with non-feasible initial points.\n* **Pitfalls of Simplex Method:**\n    * **Non-uniqueness:** Multiple optimal solutions.\n    * **Unboundedness:** No optimal solution exists.\n    * **Degeneracy:**  Multiple solutions with the same objective value.\n    * **Cycling:**  The algorithm gets stuck in a loop.\n* **Lexicogra
# ...

# %%
print(response.generations[0][0].text)
# Out:
# # Linear Programming Course Key Terms and Concepts
#
# ## Week 1
#
# * **Linear Programming:**  A mathematical method for optimizing a linear objective function subject to linear constraints.
# * **Simplex Method:** An algorithm for solving linear programming problems.
# * **Diet Problems:** A type of linear programming problem focused on optimizing the cost of a diet.
#
#
# ## Week 2
#
# * **Simplex Method (Examples):**  Illustrative applications of the simplex algorithm.
# * **Choice of Initial Point:**  Selecting a starting point for the simplex method.
# * **Phase I and Phase II:**  Stages in the simplex method, often used for problems with non-feasible initial points.
# * **Pitfalls of Simplex Method:**
#     * **Non-uniqueness:** Multiple optimal solutions.
#     * **Unboundedness:** No optimal solution exists.
#     * **Degeneracy:**  Multiple solutions with the same objective value.
#     * **Cycling:**  The algorithm gets stuck in a loop.
# ...

# %%
# what the answer could be for us to test out the LLM

key_concepts = ["Simplex Method", "Simplex Method Efficiency", "Simplex Matrix Form", "Duality", "Network Flows", "Convex Analysis", "Regression", "Integer Linear Programming", "Network Simplex Methods"]
key_problem_types = ["Network Flow Problems", "Convex Optimization Problems", "Integer Linear Programming Problems"]
key_algorithm_solutions = ["Simplex Method", "Dual Simplex Method", "Network Simplex Method", "Interior Point Method", "Ellipsoid Method"]

# %%
output = """# Linear Programming Course Key Terms and Concepts

## Week 1

* **Linear Programming:**  A mathematical method for optimizing a linear objective function subject to linear constraints.
* **Simplex Method:** An algorithm for solving linear programming problems.
* **Diet Problems:** A type of linear programming problem focused on optimizing the cost of a diet.


## Week 2

* **Simplex Method (Examples):**  Illustrative applications of the simplex algorithm.
* **Choice of Initial Point:**  Selecting a starting point for the simplex method.
* **Phase I and Phase II:**  Stages in the simplex method, often used for problems with non-feasible initial points.
* **Pitfalls of Simplex Method:**
    * **Non-uniqueness:** Multiple optimal solutions.
    * **Unboundedness:** No optimal solution exists.
    * **Degeneracy:**  Multiple solutions with the same objective value.
    * **Cycling:**  The algorithm gets stuck in a loop.
* **Lexicographic Method and Bland's Rule:** Techniques to avoid cycling in the simplex method.


## Week 3

* **Pivoting Rules:**  Different strategies for choosing the pivot element in the simplex method.
* **Efficiency of Simplex Method:**  Analysis of the algorithm's performance (average vs. worst-case).
* **Klee-Minty Example:**  Illustrates the worst-case behavior of the simplex method.
* **Ellipsoid and Interior Point Methods:**  Alternative algorithms for solving linear programming problems.
* **Duality:**  The concept of relating a primal linear programming problem to a dual problem.
* **Primal (P) and Dual (D) Problems:**  The original and related problems in duality.
* **Upper and Lower Bounds:**  Limits on the objective function value in duality.
* **Duality Gap:**  Difference between the optimal values of the primal and dual problems.
* **Weak Duality Theorem:**  A fundamental theorem in duality.


## Week 4

* **Complementary Variables:**  Variables in the primal and dual problems that are related.
* **Matrix Representation of (P) and (D):**  Representing the primal and dual problems using matrices.
* **Strong Duality Theorem:**  A theorem establishing the relationship between the optimal values of the primal and dual problems.
* **Complementary Slackness:**  A theorem relating the optimal solutions of the primal and dual problems.
* **Certificate of Optimality:**  A way to verify that a solution is optimal.


## Week 5

* **Interpretation of Duality (Cost vs. Profit):**  Understanding duality in terms of cost and profit.
* **Duality in General Form:**  Duality applied to more general linear programming problems.
* **Duality of Diet Problem:**  Applying duality to diet problems.


## Week 6

* **Simplex in Matrix Form:**  Representing the simplex method using matrices.
* **Sensitivity Analysis:**  Analyzing how changes in the problem parameters affect the optimal solution.


## Week 7

* **Sensitivity and Duality:**  Relationship between sensitivity analysis and duality.
* **Dual Simplex Method:**  An alternative simplex method for solving dual problems.
* **Dual Phase I Method:**  A method for finding a feasible solution for the dual problem.
* **Revised Simplex Method:**  An improved version of the simplex method.


## Week 8

* **Data Regression:**  Finding the best-fit line or curve to data points.
* **L^2 versus L^1:**  Different ways of measuring the error in regression.
* **L^1 Minimization as an LP Problem:**  Formulating L^1 regression as a linear programming problem.


## Week 9

* **Midterm Exam:**  A comprehensive exam covering the material from the course.


## Week 10

* **L^2, L^1, L^infinity-Regression:**  Different types of regression problems.
* **Binary Classification:**  Classifying data points into two categories.
* **Convex Analysis:**  The study of convex sets and functions.
* **Convex Set:**  A set with the property that any point on the line segment connecting two points in the set is also in the set.
* **Convex Combination:**  A weighted average of points in a convex set.
* **Convex Hull:**  The smallest convex set containing a given set of points.
* **Caratheodory Theorem:**  A theorem about convex hulls.
* **Separation Theorem:**  A theorem about separating convex sets.
* **Farkas Lemma:**  A lemma relating linear inequalities to linear equations.


## Week 11

* **Integer Linear Programming:**  A type of linear programming problem where some variables must be integers.


## Week 12

* **Network Flows:**  A type of linear programming problem dealing with flows in networks.
* **Nodes, Arcs, Networks, Incidence Matrices, Spanning Trees:**  Concepts related to network flow problems.
* **Basic Solutions in Terms of Spanning Trees:**  Solutions to network flow problems in terms of spanning trees.
* **Network Primal and Dual Simplex Methods:**  Simplex methods adapted for network flow problems.
* **Updating of Primal, Dual and Dual Slack Variables:**  Updating variables in the network simplex method.


## Week 13

* **Integrality Theorem:**  A theorem about integer solutions to linear programming problems.
* **Konig (Matching) Theorem:**  A theorem about matchings in graphs.
* **Transshipment, Transportation and Assignment Problems:**  Specific types of network flow problems.
* **Inequality Constraints for Network Flow Problems:**  Constraints related to network flow problems.
* **Upper Bounded Network Flows:**  Network flows with upper bounds on the flow.
* **Shortest Path (as a Network Flow Problem):**  Finding the shortest path between two points in a network.
* **Bellman Equation (label correcting), Dijkstra Algorithm (label setting):**  Algorithms for finding the shortest path.


## Week 14

* **Max-Flow-Min-Cut:**  A theorem relating the maximum flow in a network to the minimum cut.
* **Economic Interpretation of Network Simplex:**  Understanding the network simplex method from an economic perspective.


This list is comprehensive, but some concepts are interconnected and could be grouped more tightly for a more nuanced understanding.  For example, "Duality" is a central theme appearing in multiple weeks.

"""

# %%
prompt = "Using the outline of the course provided, sort all of these keys terms into either Key Concepts, Key Problem Types, or Key Algorithm Solutions."

message = HumanMessage(
    content=[
        {
            "type": "text", 
            "text": prompt
        },
        {
            "type": "text",
            "text": output
        }
    ]
)

response = llm.generate([[message]])
print(response)
# Out:
# generations=[[ChatGeneration(text="Based on the provided outline, here's a categorization of the key terms:\n\n**Key Concepts:**\n\n* **Linear Programming:** A mathematical method for optimizing a linear objective function subject to linear constraints.\n* **Simplex Method:** An algorithm for solving linear programming problems.\n* **Diet Problems:** A type of linear programming problem focused on optimizing the cost of a diet.\n* **Duality:** The concept of relating a primal linear programming problem to a dual problem.\n* **Primal (P) and Dual (D) Problems:** The original and related problems in duality.\n* **Upper and Lower Bounds:** Limits on the objective function value in duality.\n* **Duality Gap:** Difference between the optimal values of the primal and dual problems.\n* **Weak Duality Theorem:** A fundamental theorem in duality.\n* **Strong Duality Theorem:** A theorem establishing the relationship between the optimal values of the primal and dual problems.\n* **Complementar
# ...

# %%
print(response.generations[0][0].text)
# Out:
# Based on the provided outline, here's a categorization of the key terms:
#
# **Key Concepts:**
#
# * **Linear Programming:** A mathematical method for optimizing a linear objective function subject to linear constraints.
# * **Simplex Method:** An algorithm for solving linear programming problems.
# * **Diet Problems:** A type of linear programming problem focused on optimizing the cost of a diet.
# * **Duality:** The concept of relating a primal linear programming problem to a dual problem.
# * **Primal (P) and Dual (D) Problems:** The original and related problems in duality.
# * **Upper and Lower Bounds:** Limits on the objective function value in duality.
# * **Duality Gap:** Difference between the optimal values of the primal and dual problems.
# * **Weak Duality Theorem:** A fundamental theorem in duality.
# * **Strong Duality Theorem:** A theorem establishing the relationship between the optimal values of the primal and dual problems.
# ...
